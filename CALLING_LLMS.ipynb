# %% [markdown]
# IN THIS FILE, WE ARE GOING TO LEARN HOW TO CALL AN LLM

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from google import genai 
client = genai.Client() 
response = client.models.generate_content(
    model="gemini-3.5-flash", 
    contents="Explain how AI works in a few words" ) 
print(response.text)
# Out:
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# AI analyzes massive data, finds patterns, and makes predictions.

# %%
saman = ["aalo" , "ghost" , "hara_dhaniya", "hari_mirchain"]
','.join(saman)
# Out:
# 'aalo,ghost,hara_dhaniya,hari_mirchain'

# %%
def generate_recipe(ingradients , cuisine , diet):
    '''
        Generate a recipe using ingradients provided.
        cuisine can be "italian" , "maxican" , "Pakistani" , "Any" etc.
        diet can be "Vegan" , "Vegetarian" , "non-vegetarians" , "Any" etc.
    '''
    prompt = f"Generate one food recipe using these ingradients: {',' .join(ingradients)}Recipe should not be more then 100 wordscuisine: {cuisine}diet: {diet}"
    response = client.models.generate_content(
    model="gemini-3.5-flash", 
    contents=prompt ) 
    return response.text

# %%
recipe  = generate_recipe(["Potato" , "Meat" , "salt" , "green coriander"] , "Pakistani" , "non-vegan")
print(recipe)
# Out:
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# **Pakistani Namkeen Aloo Gosht**
#
# **Ingredients:**
# * 500g meat (mutton or beef, bone-in)
# * 2 medium potatoes (peeled and cubed)
# * Salt to taste
# * Fresh green coriander (chopped)
# * Water
#
# **Instructions:**
# 1. In a pot, add the meat, salt, and 2 cups of water. Cover and simmer on medium-low heat until the meat is half-cooked.
# 2. Stir in the cubed potatoes. Cover and cook on low heat until both the meat and potatoes are fork-tender and a light broth remains.
# 3. Garnish with fresh green coriander. Serve hot.
